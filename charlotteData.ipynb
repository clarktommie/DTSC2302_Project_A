# %%
# imports 
import pandas as pd

# %%
# Load Excel file
df = pd.read_excel('Final Project 2302 Data - group 13.xlsx')
# Show the first few rows
print(df.head())
# Out:
#    NPA median_age_of_residents_2022 high_speed_internet_access_2022  \
# 0    2                           33                           0.766
# 1    3                           31                           0.916
# 2    4                           44                           0.919
# 3    5                           31                           0.639
# 4    6                           36                           0.598
#
#   employment_2022  single_family_housing_2022_Raw residential_occupancy_2022  \
# 0           0.955                             504                       0.94
# 1           0.976                            1613                      0.864
# 2            0.98                             364                      0.897
# 3           0.847                             189                       0.94
# 4               1                             675                       0.88
#
#   home_ownership_2022  vacant_land_in_acres_2022  \
# 0               0.387                         21
# 1               0.389                         25
# 2                   1                         13
# 3               0.232                         36
# 4               0.315                         37
#
#    proximity_to_public_transportation_2022 street_connectivity_index_2022  \
# 0                                     1129                              1
# 1                                     8510                              2
# 2                                      353                              1
# 3                                      336                              1
# 4                                      811                              1
#
#    proximity_to_school_age_care_2022  \
# 0                               1121
# 1                               6605
# 2                                162
# 3                                346
# 4                                789
#
#    proximity_to_early_care_and_education_2022
# 0                                         651
# 1                                        7502
# 2                                         172
# 3                                         346
# 4                                         811

# %%
# list columns
print(df.columns)
# Out:
# Index(['NPA', 'median_age_of_residents_2022',
#        'high_speed_internet_access_2022', 'employment_2022',
#        'single_family_housing_2022_Raw', 'residential_occupancy_2022',
#        'home_ownership_2022', 'vacant_land_in_acres_2022',
#        'proximity_to_public_transportation_2022',
#        'street_connectivity_index_2022', 'proximity_to_school_age_care_2022',
#        'proximity_to_early_care_and_education_2022'],
#       dtype='object')

# %%
df.corr
# Out:
# <bound method DataFrame.corr of      NPA median_age_of_residents_2022 high_speed_internet_access_2022  \
# 0      2                           33                           0.766
# 1      3                           31                           0.916
# 2      4                           44                           0.919
# 3      5                           31                           0.639
# 4      6                           36                           0.598
# ..   ...                          ...                             ...
# 454  472                           54                           0.913
# 455  473                           42                           0.822
# 456  474                           47                            0.82
# 457  475                           50                           0.939
# 458  476                           31                           0.819
#
#     employment_2022  single_family_housing_2022_Raw  \
# 0             0.955                             504
# 1             0.976                            1613
# 2              0.98                             364
# 3             0.847                             189
# 4                 1                             675
# ..              ...                             ...
# 454               1                             514
# 455           0.988                             534
# 456               1                             632
# 457           0.953                             811
# 458           0.976                             190
#
#     residential_occupancy_2022 home_ownership_2022  vacant_land_in_acres_2022  \
# 0                         0.94               0.387                         21
# 1                        0.864               0.389                         25
# 2                        0.897                   1                         13
# 3                         0.94               0.232                         36
# 4                         0.88               0.315                         37
# ..                         ...                 ...                        ...
# 454                      0.876               0.765                         60
# 455                      0.898               0.618                        107
# 456                      0.901               0.791                         37
# 457                      0.857               0.773                        109
# 458                      0.821               0.265                         29
#
#      proximity_to_public_transportation_2022 street_connectivity_index_2022  \
# 0                                       1129                              1
# 1                                       8510                              2
# 2                                        353                              1
# 3                                        336                              1
# 4                                        811                              1
# ..                                       ...                            ...
# 454                                        0                              1
# 455                                     1117                              1
# 456                                      746                              1
# 457                                      824                              1
# 458                                    13800                              2
#
#      proximity_to_school_age_care_2022  \
# 0                                 1121
# 1                                 6605
# 2                                  162
# 3                                  346
# 4                                  789
# ..                                 ...
# 454                                 89
# 455                                409
# 456                                557
# 457                                305
# 458                              12426
#
#      proximity_to_early_care_and_education_2022
# 0                                           651
# 1                                          7502
# 2                                           172
# 3                                           346
# 4                                           811
# ..                                          ...
# 454                                          89
# 455                                         796
# 456                                         557
# 457                                         198
# 458                                       13700
#
# [459 rows x 12 columns]>

# %%
# check for null valeus
print(df.isnull())
# Out:
#        NPA  median_age_of_residents_2022  high_speed_internet_access_2022  \
# 0    False                         False                            False
# 1    False                         False                            False
# 2    False                         False                            False
# 3    False                         False                            False
# 4    False                         False                            False
# ..     ...                           ...                              ...
# 454  False                         False                            False
# 455  False                         False                            False
# 456  False                         False                            False
# 457  False                         False                            False
# 458  False                         False                            False
#
#      employment_2022  single_family_housing_2022_Raw  \
# 0              False                           False
# 1              False                           False
# 2              False                           False
# 3              False                           False
# 4              False                           False
# ..               ...                             ...
# 454            False                           False
# 455            False                           False
# 456            False                           False
# 457            False                           False
# 458            False                           False
#
#      residential_occupancy_2022  home_ownership_2022  \
# 0                         False                False
# 1                         False                False
# 2                         False                False
# 3                         False                False
# 4                         False                False
# ..                          ...                  ...
# 454                       False                False
# 455                       False                False
# 456                       False                False
# 457                       False                False
# 458                       False                False
#
#      vacant_land_in_acres_2022  proximity_to_public_transportation_2022  \
# 0                        False                                    False
# 1                        False                                    False
# 2                        False                                    False
# 3                        False                                    False
# 4                        False                                    False
# ..                         ...                                      ...
# 454                      False                                    False
# 455                      False                                    False
# 456                      False                                    False
# 457                      False                                    False
# 458                      False                                    False
#
#      street_connectivity_index_2022  proximity_to_school_age_care_2022  \
# 0                             False                              False
# 1                             False                              False
# 2                             False                              False
# 3                             False                              False
# 4                             False                              False
# ..                              ...                                ...
# 454                           False                              False
# 455                           False                              False
# 456                           False                              False
# 457                           False                              False
# 458                           False                              False
#
#      proximity_to_early_care_and_education_2022
# 0                                         False
# 1                                         False
# 2                                         False
# 3                                         False
# 4                                         False
# ..                                          ...
# 454                                       False
# 455                                       False
# 456                                       False
# 457                                       False
# 458                                       False
#
# [459 rows x 12 columns]

# %%
missing_per_column = df.isnull().sum()
print(missing_per_column)
# Out:
# NPA                                           0
# median_age_of_residents_2022                  0
# high_speed_internet_access_2022               0
# employment_2022                               0
# single_family_housing_2022_Raw                0
# residential_occupancy_2022                    0
# home_ownership_2022                           0
# vacant_land_in_acres_2022                     0
# proximity_to_public_transportation_2022       0
# street_connectivity_index_2022                0
# proximity_to_school_age_care_2022             0
# proximity_to_early_care_and_education_2022    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Calculate correlation matrix
corr = df.corr(numeric_only=True)

# Set up the matplotlib figure
plt.figure(figsize=(10, 8))

# Draw the heatmap
sns.heatmap(corr, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5, square=True)

# Add title
plt.title("Correlation Matrix Heatmap")

# Show the plot
plt.show()
